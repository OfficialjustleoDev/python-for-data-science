# %%
# Load data from a CSV file into a Pandas DataFrame and display the first 5 rows using head()
df = pd.read_csv("medical_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load data from a CSV file into a Pandas DataFrame and display the first 5 rows using head()
# ----> 2 df = pd.read_csv("medical_data.csv")
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
# Display summary information about the DataFrame i.e. size of your dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
# Display statistical summary of numerical columns in the DataFrame i.e. mean, median, standard deviation, etc.
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
# Create a histogram to visualize the distribution of the 'Age' column i.e. how many patients fall into different age groups
df['Age']
# Out:
# 0        30
# 1        62
# 2        76
# 3        28
# 4        43
#          ..
# 55495    42
# 55496    61
# 55497    38
# 55498    43
# 55499    53
# Name: Age, Length: 55500, dtype: int64

# %%
# Group the data by 'AppointmentStatus' and count the number of occurrences in each group
df[['Age', 'Gender']]
# Out:
#        Age  Gender
# 0       30    Male
# 1       62    Male
# 2       76  Female
# 3       28  Female
# 4       43  Female
# ...    ...     ...
# 55495   42  Female
# 55496   61  Female
# 55497   38  Female
# 55498   43    Male
# 55499   53  Female
#
# [55500 rows x 2 columns]

# %%
# Filter the DataFrame to show only patients older than 60 years
df[df['Age'] > 60]
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...                 ...  ...     ...        ...               ...
# 55487    mIsTy RICharDs   78  Female         O-      Hypertension
# 55489    ANdrEw AGUIlaR   69    Male         O-         Arthritis
# 55490  STepHAniE oliVer   82    Male         B-            Cancer
# 55494     JEssIcA WHiTe   67    Male         O+         Arthritis
# 55496        KYle pEREz   61  Female        AB-           Obesity
#
#       Date of Admission            Doctor                   Hospital  \
# 1            2019-08-20   Samantha Davies                    Kim Inc
# ...

# %%
# Filter the DataFrame to show only female
df[df['Gender'] == 'Female']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 2             DaNnY sMitH   76  Female         A-           Obesity
# 3            andrEw waTtS   28  Female         O+          Diabetes
# 4           adrIENNE bEll   43  Female        AB+            Cancer
# 6          edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# ...                   ...  ...     ...        ...               ...
# 55493        gLoRIA BOWen   57  Female         B-         Arthritis
# 55495   eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496          KYle pEREz   61  Female        AB-           Obesity
# 55497        HEATher WaNG   38  Female         B+      Hypertension
# 55499        jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# ...

# %%
# Filter the DataFrame to show only female patients older than 60 years
df[(df['Age'] > 60) & (df['Gender'] == 'Female')]
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 12      connOR HANsEn   75  Female         A+          Diabetes
# 13       rObeRt bAuer   68  Female        AB+            Asthma
# 16      haley perkins   63  Female         A+         Arthritis
# 20      tIMOTHY burNs   67  Female         A-            Asthma
# ...               ...  ...     ...        ...               ...
# 55467     SaNDrA ChEN   62  Female         B+            Asthma
# 55471      iaN MuRpHy   73  Female         B+      Hypertension
# 55486   AngelA LEstER   83  Female         B+            Asthma
# 55487  mIsTy RICharDs   78  Female         O-      Hypertension
# 55496      KYle pEREz   61  Female        AB-           Obesity
#
#       Date of Admission            Doctor                     Hospital  \
# 2            2022-09-22  Tiffany Mitchell                     Cook PLC
# ...

# %%
# Check for missing values in the DataFrame 
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
# Drop rows with any missing values from the DataFrame
df = df.dropna()

# %%
# Fill missing values in the 'Age' column with the mean age
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# Group the data by 'Gender' and calculate the average age for each group 
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    51.578735
# Male      51.500252
# Name: Age, dtype: float64

# %%
# Group the data by 'Gender     ' and count the number of occurrences in each group
df.groupby('Gender').size()
# Out:
# Gender
# Female    27726
# Male      27774
# dtype: int64

# %%
# Create a histogram to visualize the distribution of the 'Age' column i.e. how many patients fall into different age groups
df['Age'].hist()
plt.show()

# %%
# Create a bar chart to visualize the count of patients by gender
df['Gender'].value_counts().plot(kind='bar')
plt.show()

# %%
# Create a bar chart to visualize the average age of patients by gender
df.groupby('Gender')['Age'].mean().plot(kind='bar')
plt.show()

# %%
# Import NumPy and create a simple array
import numpy as np
arr = np.array([1, 2, 3, 4, 5])

# %%
# Calculate the mean of the NumPy array
arr.mean()
# Out:
# np.float64(3.0)

# %%
# Calculate the maximum value in the NumPy array
arr.max()
# Out:
# np.int64(5)

# %%
# Multiply each element in the NumPy array by 2
arr * 2
# Out:
# array([ 2,  4,  6,  8, 10])
